# %%
import pandas as pd
d=pd.read_csv('/content/diabetes (1).csv')
print(d)
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
x1=d['Pregnancies']
x2=d['Glucose']
x3=d['BloodPressure']
x4=d['SkinThickness']
x5=d['Insulin']
x6=d['BMI']
x7=d['DiabetesPedigreeFunction']
y=d['Age']
print(x1,x2,x3,x4,x5,x6,x7,y)
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
#        ..
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: Pregnancies, Length: 768, dtype: int64 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64 0      72
# 1      66
# 2      64
# 3      66
# 4      40
#        ..
# 763    76
# 764    70
# 765    72
# 766    60
# 767    70
# Name: BloodPressure, Length: 768, dtype: int64 0      35
# 1      29
# 2       0
# 3      23
# 4      35
#        ..
# 763    48
# 764    27
# 765    23
# 766     0
# 767    31
# Name: SkinThickness, Length: 768, dtype: int64 0        0
# 1        0
# 2        0
# 3       94
# 4      168
#       ...
# 763    180
# 764      0
# 765    112
# 766      0
# 767      0
# Name: Insulin, Length: 768, dtype: int64 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# ...

# %%
import numpy as np


def linear(m,m1,m2,m3,m4,m5,m6,c):
  sum=0
  yp=[]
  e=[]

  for i in range(0,len(x7)):
    yp.append(m*x1[i]+m1*x2[i]+m2*x3[i]+m3*x4[i]+m4*x5[i]+m5*x6[i]+m6*x7[i]+c)
    g=(y[i]-yp[i])**2
    sum=sum+g
    e.append(g)
    print(m,m1,m2,m3,m4,m5,m6,c,np.mod(sum,len(x7)))
    sum=0

for i in range(1,1000):
  linear(1+i,2+i,3+i,4+i,5+i,6+i,7+i,11+i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 994 995 996 997 998 999 1000 1004 231.0399932861328
# 994 995 996 997 998 999 1000 1004 211.239990234375
# 994 995 996 997 998 999 1000 1004 101.29000854492188
# 994 995 996 997 998 999 1000 1004 88.3599853515625
# 994 995 996 997 998 999 1000 1004 307.8400115966797
# 994 995 996 997 998 999 1000 1004 241.0
# 994 995 996 997 998 999 1000 1004 31.3599853515625
# 994 995 996 997 998 999 1000 1004 682.8099975585938
# 994 995 996 997 998 999 1000 1004 109.29000854492188
# 994 995 996 997 998 999 1000 1004 752.890007019043
# 994 995 996 997 998 999 1000 1004 289.69000244140625
# 994 995 996 997 998 999 1000 1004 675.6900024414062
# 994 995 996 997 998 999 1000 1004 64.0
# 994 995 996 997 998 999 1000 1004 473.760009765625
# 994 995 996 997 998 999 1000 1004 393.0
# 994 995 996 997 998 999 1000 1004 245.2899932861328
# 994 995 996 997 998 999 1000 1004 228.49005126953125
# 994 995 996 997 998 999 1000 1004 298.8100128173828
# ...

# %%
j_test=d[0:500: ]
j_train=d[501:768: ]
print( j_test)
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 495            6      166  ...   66        0
# 496            5      110  ...   30        0
# 497            2       81  ...   25        0
# 498            7      195  ...   55        1
# 499            6      154  ...   39        0
#
# [500 rows x 9 columns]

# %%
j_train=d[501:768: ]
print(j_train )
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 501            3       84  ...   28        0
# 502            6        0  ...   41        1
# 503            7       94  ...   41        0
# 504            3       96  ...   40        0
# 505           10       75  ...   38        0
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [267 rows x 9 columns]

# %%
from matplotlib import pyplot as pt
pt.scatter(x1,y)

# %%
pt.scatter(x2,y)

# %%
pt.scatter(x3,y)

# %%
pt.scatter(x4,y)

# %%
pt.scatter(x5,y)

# %%
pt.scatter(x6,y)

# %%
pt.scatter(x6,y)

# %%
pt.scatter(x7,y)
